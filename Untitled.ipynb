# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
from bs4 import BeautifulSoup

data = pd.read_csv("newsdataset.csv")
data.head(4000)
# Out:
#            id                                              title  \
# 0     5917282  اوباما: نژادپرستی در جامعه آمریکا ریشه دوانده ...
# 1     5917280       مرقومه رهبر انقلاب برای همایش مقابله با فساد
# 2     5917279                   گلایه وزیر ارشاد از بودجه فرهنگی
# 3     5917278       توضیحات تازه سیف درباره فساد 12هزار میلیاردی
# 4     5917277             ناوگروه نیروی دریایی ارتش وارد عمان شد
# 5     5917276             آگهی دولتی به چه نشریاتی تعلق می گیرد؟
# 6     5917275         عراقی‌ها با خودروهای شخصی به ایران می‌آیند
# 7     5917274            جزئیات دستگیری گروه عرفان کیهانی در کیش
# 8     5917273          صدور گواهی فوت برای نوزاد زنده در خوزستان
# 9     5917272            افزایش 14 درصدی حقوق کارمندان در سال 94
# 10    5917271       اظهارات دادستان تهران درباره فساد اخیر بانکی
# 11    5917270           شرط آمریکا برای ایجاد منطقه امن در سوریه
# 12    5917269              توقف انتقال نفت کردستان عراق به ترکیه
# ...

# %%
netflix = { 'title': list(data.title)[:100], 'summary': list(data.summary)[:100], 'source': list(data.source)[:100], 'keyword': list(data.keyword)[:100], 'cluster': clusters[:100] }
frame = pd.DataFrame(data, index = [clusters[:100]] , columns = ['title', 'summary', 'source', 'keyword', 'cluster'])

# %%
data = []
for text in data:
    text = BeautifulSoup(text, 'html.parser').getText()
    #strips html formatting and converts to unicode
    data.append(text)

# %%
stop_words = open('persianstops.txt'.encode('utf-8'))

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("farsi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-352-6391d0930a5c> in <module>()
#       1 from nltk.stem.snowball import SnowballStemmer
# ----> 2 stemmer = SnowballStemmer("farsi")
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\stem\snowball.py in __init__(self, language, ignore_stopwords)
#      94     def __init__(self, language, ignore_stopwords=False):
#      95         if language not in self.languages:
# ---> 96             raise ValueError("The language '{0}' is not supported.".format(language))
#      97         stemmerclass = globals()[language.capitalize() + "Stemmer"]
#      98         self.stemmer = stemmerclass(ignore_stopwords)
#
# ValueError: The language 'farsi' is not supported.

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in netflix:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print ('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 0 items in vocab_frame

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(list(data.description))

# %%
terms = vectorizer.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(X[:100])

# %%
true_k = 5
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
clusters = model.labels_.tolist()
order_centroids = model.cluster_centers_.argsort()[:, ::-1]

# %%
from __future__ import print_function

print("Most trending terms per a cluster:")
print()

for i in range(true_k):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :5]:
        print(terms[ind])
    print() 
    print()
    
    print("Cluster %d titles:" % i, end='')
    for title in frame.loc[[i]]['title']:
        print(' %s,' % title, end='')
    print()
    print()


print()
print()
# Out:
# Most trending terms per a cluster:
#
# Cluster 0:
# school
# high
# special
# stand
# students
#
#
# Cluster 0 titles: #realityhigh, Lovesick, Domino, Lessons from a School Shooting: Notes from Dunblane,
#
# Cluster 1:
# love
# group
# women
# young
# life
#
#
# Cluster 1 titles: Manhattan Romance, City of Joy, Care of Kancharapalem, Bangkok Traffic (Love) Story, Suckseed, Christiane Amanpour: Sex & Love Around the World, Mak Cun, The Sinking Of Van Der Wijck,
#
# Cluster 2:
# murder
# team
# cop
# case
# detective
#
#
# Cluster 2 titles: Krish Trish and Baltiboy, Krish Trish and Baltiboy: Best Friends Forever, Article 15, Big Miracle, Amanda Knox, Paradise Lost, Long Shot,
#
# Cluster 3:
# life
# new
# york
# family
# young
#
#
# Cluster 3 titles: Transformers: Robots in Disguise, Apaches, Rolling Papers, The Runner, Castle of Stars, First and Last, Archibald's Next Big Thing, ATM, No Tomorrow, Black Panther, Act of Vengeance, Satu Hari,
#
# Cluster 4:
# young
# family
# world
# ...

# %%
import os 

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist) 
xs, ys = pos[:, 0], pos[:, 1]

# %%
cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#45b6fe'}

cluster_names = {0: 'New, life, family, world, friends', 
                 1: 'Save, fight, american, future, brothers', 
                 2: 'Drama, stories, set, writer, single', 
                 3: 'Yound, man, women, life, father', 
                 4: 'Documentary, follows, explores, series, world'}

# %%
# %matplotlib inline 
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

df = pd.DataFrame(dict(x=xs, y=ys, label=clusters[:100], title=list(data.title)[:100])) 
groups = df.groupby('label')

fig, ax = plt.subplots(figsize=(17, 9))
ax.margins(0.05) 

for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, 
            label=cluster_names[name], color=cluster_colors[name], 
            mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',        
        which='both',    
        bottom='off',   
        top='off',       
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',       
        which='both',     
        left='off',     
        top='off',       
        labelleft='off')
    
ax.legend(numpoints=1) 

for i in range(len(df)):
    ax.text(df.iloc[i]['x'], df.iloc[i]['y'], df.iloc[i]['title'], size=8)  

    
plt.figure(figsize=(100,80),dpi=100)
plt.show()

# %%
tokens = nltk.word_tokenize(data)
for token in tokens:
    if(token.find("\u200c")!=-1):
        tokens.remove(token)
        
    elif(token.find("\ufeff")!=-1):
                tokens.remove(token)
        
    
    print(len(tokens))
    print(tokens)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-7112121f08f9> in <module>()
# ----> 1 tokens = nltk.word_tokenize(data)
#       2 for token in tokens:
#       3     if(token.find("\u200c")!=-1):
#       4         tokens.remove(token)
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ...
